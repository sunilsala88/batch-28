# %%
from alpaca.trading.client import TradingClient
from credentials import api_key,secret_key
trading_client = TradingClient(api_key, secret_key, paper=True)

account = trading_client.get_account()
account
# Out:
# {   'account_blocked': False,
#     'account_number': 'PA32II6CTZQA',
#     'accrued_fees': '0',
#     'buying_power': '3903877.86',
#     'cash': '936187.14',
#     'created_at': datetime.datetime(2024, 8, 24, 9, 13, 29, 133143, tzinfo=TzInfo(UTC)),
#     'crypto_status': <AccountStatus.ACTIVE: 'ACTIVE'>,
#     'currency': 'USD',
#     'daytrade_count': 0,
#     'daytrading_buying_power': '3903877.86',
#     'equity': '1004491.64',
#     'id': UUID('28959f70-ced0-4150-a908-c1d2ef1a475a'),
#     'initial_margin': '30807.03',
#     'last_equity': '1004499.723186846795',
#     'last_maintenance_margin': '18484.22',
#     'long_market_value': '68195.52',
#     'maintenance_margin': '18484.22',
#     'multiplier': '4',
#     'non_marginable_buying_power': '964612.12',
#     'options_approved_level': 2,
#     'options_buying_power': '978934.93',
#     'options_trading_level': 2,
#     'pattern_day_trader': True,
#     'pending_transfer_in': None,
#     'pending_transfer_out': None,
# ...

# %%
import pandas as pd
df=pd.Series(dict(account))
df.to_csv('data.csv')

# %% [markdown]
# # position

# %%
pos=trading_client.get_all_positions()
pos
# Out:
# [{   'asset_class': <AssetClass.CRYPTO: 'crypto'>,
#      'asset_id': UUID('35f33a69-f5d6-4dc9-b158-4485e5e92e4b'),
#      'asset_marginable': False,
#      'avg_entry_price': '4011.611272619',
#      'avg_entry_swap_rate': None,
#      'change_today': '0.0022653697487159',
#      'cost_basis': '12052.305584',
#      'current_price': '3351.4',
#      'exchange': <AssetExchange.CRYPTO: 'CRYPTO'>,
#      'lastday_price': '3343.825',
#      'market_value': '10068.796349',
#      'qty': '3.004355299',
#      'qty_available': '3.004355299',
#      'side': <PositionSide.LONG: 'long'>,
#      'swap_rate': None,
#      'symbol': 'ETHUSD',
#      'unrealized_intraday_pl': '22.757991',
#      'unrealized_intraday_plpc': '0.0022653697098297',
#      'unrealized_pl': '-1983.509235',
#      'unrealized_plpc': '-0.1645750865820397',
#      'usd': None},
#  {   'asset_class': <AssetClass.US_EQUITY: 'us_equity'>,
#      'asset_id': UUID('f30d734c-2806-4d0d-b145-f9fade61432b'),
# ...

# %%
list_of_dict=[]
for i in pos:
    list_of_dict.append(dict(i))
pos_df=pd.DataFrame(list_of_dict)
pos_df.to_csv('position.csv')
pos_df
# Out:
#                                asset_id  symbol              exchange  \
# 0  35f33a69-f5d6-4dc9-b158-4485e5e92e4b  ETHUSD  AssetExchange.CRYPTO
# 1  f30d734c-2806-4d0d-b145-f9fade61432b    GOOG  AssetExchange.NASDAQ
# 2  4ce9353c-66d1-46c2-898f-fce867ab0247    NVDA  AssetExchange.NASDAQ
# 3  b28f4066-5c6d-479b-a2af-85dc1a8f16fb     SPY    AssetExchange.ARCA
#
#             asset_class  asset_marginable avg_entry_price           qty  \
# 0     AssetClass.CRYPTO             False  4011.611272619   3.004355299
# 1  AssetClass.US_EQUITY              True          200.23  -0.984462847
# 2  AssetClass.US_EQUITY              True          148.41             1
# 3  AssetClass.US_EQUITY              True      607.147767           103
#
#                  side  market_value    cost_basis  ...      unrealized_plpc  \
# 0   PositionSide.LONG  10068.796349  12052.305584  ...  -0.1645750865820397
# 1  PositionSide.SHORT   -191.025171   -197.118996  ...    0.030914448245262
# ...

# %% [markdown]
# # order book

# %%
ord=trading_client.get_orders()
ord
# Out:
# [{   'asset_class': <AssetClass.CRYPTO: 'crypto'>,
#      'asset_id': UUID('8588af33-3a8e-4a09-bb6c-ba4226dc7aff'),
#      'canceled_at': None,
#      'client_order_id': '653fe584-4d75-41ca-81b1-cce11099a854',
#      'created_at': datetime.datetime(2024, 12, 29, 13, 56, 8, 839588, tzinfo=TzInfo(UTC)),
#      'expired_at': None,
#      'extended_hours': False,
#      'failed_at': None,
#      'filled_at': None,
#      'filled_avg_price': None,
#      'filled_qty': '0',
#      'hwm': None,
#      'id': UUID('12424f90-8a1c-4d60-b4ee-ef4f1595b37c'),
#      'legs': None,
#      'limit_price': '300',
#      'notional': None,
#      'order_class': <OrderClass.SIMPLE: 'simple'>,
#      'order_type': <OrderType.LIMIT: 'limit'>,
#      'qty': '1',
#      'replaced_at': None,
#      'replaced_by': None,
#      'replaces': None,
#      'side': <OrderSide.BUY: 'buy'>,
#      'status': <OrderStatus.NEW: 'new'>,
#      'stop_price': None,
# ...

# %%
import pandas as pd
list_of_dict=[]
for i in ord:
    list_of_dict.append(dict(i))
ord_df=pd.DataFrame(list_of_dict)
ord_df.to_csv('orders.csv')
ord_df
# Out:
#                                      id                       client_order_id  \
# 0  12424f90-8a1c-4d60-b4ee-ef4f1595b37c  653fe584-4d75-41ca-81b1-cce11099a854
#
#                         created_at                       updated_at  \
# 0 2024-12-29 13:56:08.839588+00:00 2024-12-29 13:56:08.874760+00:00
#
#                       submitted_at filled_at expired_at canceled_at failed_at  \
# 0 2024-12-29 13:56:08.839588+00:00      None       None        None      None
#
#   replaced_at  ...           side    time_in_force limit_price stop_price  \
# 0        None  ...  OrderSide.BUY  TimeInForce.GTC         300       None
#
#             status extended_hours  legs trail_percent trail_price   hwm
# 0  OrderStatus.NEW          False  None          None        None  None
#
# [1 rows x 32 columns]

# %%
trading_client.close_position('DOGEUSD')
# Out:
# {   'asset_class': <AssetClass.CRYPTO: 'crypto'>,
#     'asset_id': UUID('03e005f7-4bfc-4616-b1b0-225dd64074fa'),
#     'canceled_at': None,
#     'client_order_id': '7a9302c3-d6ba-4e96-87ae-81a5d54be5a1',
#     'created_at': datetime.datetime(2024, 12, 29, 13, 53, 48, 872098, tzinfo=TzInfo(UTC)),
#     'expired_at': None,
#     'extended_hours': False,
#     'failed_at': None,
#     'filled_at': None,
#     'filled_avg_price': None,
#     'filled_qty': '0',
#     'hwm': None,
#     'id': UUID('83f017e5-b375-4d17-8fb9-79333ed30895'),
#     'legs': None,
#     'limit_price': None,
#     'notional': None,
#     'order_class': <OrderClass.SIMPLE: 'simple'>,
#     'order_type': <OrderType.MARKET: 'market'>,
#     'qty': '0.9978',
#     'replaced_at': None,
#     'replaced_by': None,
#     'replaces': None,
#     'side': <OrderSide.SELL: 'sell'>,
#     'status': <OrderStatus.PENDING_NEW: 'pending_new'>,
#     'stop_price': None,
# ...

# %%
trading_client.cancel_order_by_id('499a9b80-b9a9-41ee-acef-0c61e10ce1dc')

# %%
inst_name='AAVE/USD'
for i in trading_client.get_orders():
    if i.symbol==inst_name:
        id1=i.id
        
id1
# Out:
# UUID('12424f90-8a1c-4d60-b4ee-ef4f1595b37c')

# %%
trading_client.cancel_order_by_id(id1)
