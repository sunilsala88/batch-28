# %%
import pandas as pd

# %%
company = pd.read_csv('Unicorn_companies.csv')
company.head()
# Out:
#      Company  Valuation Date Joined                         Industry  \
# 0  Bytedance        180  07-04-2017          Artificial intelligence
# 1     SpaceX        100  01-12-2012                            Other
# 2      SHEIN        100  03-07-2018  E-commerce & direct-to-consumer
# 3     Stripe         95  23-01-2014                          Fintech
# 4     Klarna         46  12-12-2011                          Fintech
#
#             City        Country      Continent  Year Founded  Funding
# 0        Beijing          China           Asia          2012      NaN
# 1      Hawthorne  United States  North America          2002      7.0
# 2       Shenzhen          China           Asia          2008      2.0
# 3  San Francisco  United States  North America          2010      2.0
# 4      Stockholm         Sweden         Europe          2005      4.0

# %%
company.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1074 entries, 0 to 1073
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Company       1074 non-null   object
#  1   Valuation     1074 non-null   float64
#  2   Date Joined   1074 non-null   object
#  3   Industry      1074 non-null   object
#  4   City          1058 non-null   object
#  5   Country       1074 non-null   object
#  6   Continent     1074 non-null   object
#  7   Year Founded  1074 non-null   int64
#  8   Funding       1073 non-null   float64
# dtypes: float64(2), int64(1), object(6)
# memory usage: 75.6+ KB

# %%
company['Funding']=company['Funding'].astype(int)
# Out:
# ---------------------------------------------------------------------------
# IntCastingNaNError                        Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 company['Funding']=company['Funding'].astype(int)
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pandas/core/generic.py:6643, in NDFrame.astype(self, dtype, copy, errors)
#    6637     results = [
#    6638         ser.astype(dtype, copy=copy, errors=errors) for _, ser in self.items()
#    6639     ]
#    6641 else:
#    6642     # else, only a single dtype is given
# -> 6643     new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    6644     res = self._constructor_from_mgr(new_data, axes=new_data.axes)
#    6645     return res.__finalize__(self, method="astype")
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pandas/core/internals/managers.py:430, in BaseBlockManager.astype(self, dtype, copy, errors)
# ...

# %%
list(company.columns)
# Out:
# ['Company',
#  'Valuation',
#  'Date Joined',
#  'Industry',
#  'City',
#  'Country',
#  'Continent',
#  'Year Founded',
#  'Funding']

# %%
#drop a row 
company.drop(1,axis=0,inplace=True)
company
# Out:
#            Company  Valuation Date Joined  \
# 3           Stripe       95.0  23-01-2014
# 4           Klarna       46.0  12-12-2011
# 5            Canva       40.0  08-01-2018
# 6     Checkout.com       40.0  02-05-2019
# 7        Instacart       39.0  30-12-2014
# ...            ...        ...         ...
# 1069      Zhaogang        1.0  29-06-2017
# 1070   Zhuan Zhuan        1.0  18-04-2017
# 1071      Zihaiguo        1.0  06-05-2021
# 1072          Zopa        1.0  19-10-2021
# 1073         Zwift        1.0  16-09-2020
#
#                                  Industry           City         Country  \
# 3                                 Fintech  San Francisco   United States
# 4                                 Fintech      Stockholm          Sweden
# 5            Internet software & services    Surry Hills       Australia
# 6                                 Fintech         London  United Kingdom
# 7     Supply chain, logistics, & delivery  San Francisco   United States
# ...

# %%
#drop a column
company=company.drop('Funding',axis=1)
company
# Out:
#           Company  Valuation Date Joined                         Industry  \
# 0       Bytedance        180  07-04-2017          Artificial intelligence
# 1          SpaceX        100  01-12-2012                            Other
# 3          Stripe         95  23-01-2014                          Fintech
# 4          Klarna         46  12-12-2011                          Fintech
# 5           Canva         40  08-01-2018     Internet software & services
# ...           ...        ...         ...                              ...
# 1069     Zhaogang          1  29-06-2017  E-commerce & direct-to-consumer
# 1070  Zhuan Zhuan          1  18-04-2017  E-commerce & direct-to-consumer
# 1071     Zihaiguo          1  06-05-2021                Consumer & retail
# 1072         Zopa          1  19-10-2021                          Fintech
# 1073        Zwift          1  16-09-2020  E-commerce & direct-to-consumer
#
#                City         Country      Continent  Year Founded
# ...

# %%
company.drop([3,4,5],axis=0)

# %%
company.drop(['Industry','Country'],axis=1)
company

# %%
company['Year Founded']=company['Year Founded'].astype(str)

# %%
company.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1073 entries, 0 to 1073
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Company       1073 non-null   object
#  1   Valuation     1073 non-null   int64
#  2   Date Joined   1073 non-null   object
#  3   Industry      1073 non-null   object
#  4   City          1057 non-null   object
#  5   Country       1073 non-null   object
#  6   Continent     1073 non-null   object
#  7   Year Founded  1073 non-null   object
# dtypes: int64(1), object(7)
# memory usage: 75.4+ KB

# %%
company["Funding"][6]

# %%
company
# Out:
#            Company  Valuation Date Joined  \
# 3           Stripe       95.0  23-01-2014
# 4           Klarna       46.0  12-12-2011
# 5            Canva       40.0  08-01-2018
# 6     Checkout.com       40.0  02-05-2019
# 7        Instacart       39.0  30-12-2014
# ...            ...        ...         ...
# 1069      Zhaogang        1.0  29-06-2017
# 1070   Zhuan Zhuan        1.0  18-04-2017
# 1071      Zihaiguo        1.0  06-05-2021
# 1072          Zopa        1.0  19-10-2021
# 1073         Zwift        1.0  16-09-2020
#
#                                  Industry           City         Country  \
# 3                                 Fintech  San Francisco   United States
# 4                                 Fintech      Stockholm          Sweden
# 5            Internet software & services    Surry Hills       Australia
# 6                                 Fintech         London  United Kingdom
# 7     Supply chain, logistics, & delivery  San Francisco   United States
# ...

# %%
company.drop_duplicates(subset='City')
# Out:
#                     Company  Valuation Date Joined  \
# 3                    Stripe       95.0  23-01-2014
# 4                    Klarna       46.0  12-12-2011
# 5                     Canva       40.0  08-01-2018
# 6              Checkout.com       40.0  02-05-2019
# 11               Epic Games       32.0  26-10-2018
# ...                     ...        ...         ...
# 1011             ReliaQuest        1.0  01-12-2021
# 1012  Revolution Precrafted        1.0  23-10-2017
# 1016               Scalapay        1.0  23-02-2022
# 1036                  Swile        1.0  11-10-2021
# 1037        Tarana Wireless        1.0  23-03-2022
#
#                           Industry           City         Country  \
# 3                          Fintech  San Francisco   United States
# 4                          Fintech      Stockholm          Sweden
# 5     Internet software & services    Surry Hills       Australia
# 6                          Fintech         London  United Kingdom
# ...

# %%
unique_company = company.drop_duplicates(subset=['City','Country'])
unique_company
